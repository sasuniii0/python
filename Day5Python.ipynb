# %%
x =10
isinstance(x , int)

# %%
x = "is"
isinstance(x , (int , float))

# %%
x = 10
print(f"the value of x is {x}")

# %%
class Parrot:
    name = "Peththappu"
    age =  1

parrot_1 = Parrot()
print(parrot_1.name)
print(parrot_1.age)

# %%
class Player:
    score = 10

    def add_points(self, score):
        new_score = self.score + score
        return new_score

player_1 = Player()
print(f"score of player_1 is {player_1.add_points(4)}")
# Out:
# score of player_1 is 14
