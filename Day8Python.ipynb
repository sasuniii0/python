# %%
import requests
print(requests.__version__)
# Out:
# 2.32.5

# %%
import requests 

url = 'https://api.github.com/events'
response = requests.get(url)

print(response)
print(type(response))
print(response.status_code)
print(response.headers)
# Out:
# <Response [200]>
# <class 'requests.models.Response'>
# 200
# {'Date': 'Fri, 19 Dec 2025 04:40:06 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Cache-Control': 'public, max-age=300, s-maxage=300', 'Vary': 'Accept,Accept-Encoding, Accept, X-Requested-With', 'ETag': 'W/"cfb01fad1dcce065dd5a384a675203ba1dda6c6e5c7105d30dabc512568138ad"', 'Last-Modified': 'Fri, 19 Dec 2025 04:35:05 GMT', 'X-Poll-Interval': '60', 'X-GitHub-Media-Type': 'github.v3; format=json', 'Link': '<https://api.github.com/events?page=2>; rel="next", <https://api.github.com/events?page=10>; rel="last"', 'x-github-api-version-selected': '2022-11-28', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Resource, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, X-GitHub-SSO, X-GitHub-Request-Id, Deprecation, Sunset', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Frame-Options': 'deny', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '0', 'Referrer-Policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'Content-Security-Policy': "default-src 'none'", 'Content-Encoding': 'gzip', 'Server': 'github.com', 'Accept-Ranges': 'bytes', 'X-RateLimit-Limit': '60', 'X-RateLimit-Remaining': '51', 'X-RateLimit-Reset': '1766122420', 'X-RateLimit-Resource': 'core', 'X-RateLimit-Used': '9', 'Transfer-Encoding': 'chunked', 'X-GitHub-Request-Id': '4369:4D39E:3B4F20:451A6C:6944D726'}

# %%
import requests

url = 'https://api.github.com/events'
response = requests.get(url)

if response.status_code == 200:
    print('Fetching Successful!')
else:
    print( 'Fetching Failed', response.status_code)
# Out:
# Fetching Successful!

# %%
import requests 

url = 'https://api.github.com/events'
response = requests.get(url)

print(response.status_code)
print(response.headers)
print(response.headers['Content-Type'])
print(response.text)
# Out:
# 200
# {'Date': 'Fri, 19 Dec 2025 04:40:06 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Cache-Control': 'public, max-age=300, s-maxage=300', 'Vary': 'Accept,Accept-Encoding, Accept, X-Requested-With', 'ETag': 'W/"cfb01fad1dcce065dd5a384a675203ba1dda6c6e5c7105d30dabc512568138ad"', 'Last-Modified': 'Fri, 19 Dec 2025 04:35:05 GMT', 'X-Poll-Interval': '60', 'X-GitHub-Media-Type': 'github.v3; format=json', 'Link': '<https://api.github.com/events?page=2>; rel="next", <https://api.github.com/events?page=10>; rel="last"', 'x-github-api-version-selected': '2022-11-28', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Resource, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, X-GitHub-SSO, X-GitHub-Request-Id, Deprecation, Sunset', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Frame-Options': 'deny', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '0', 'Referrer-Policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'Content-Security-Policy': "default-src 'none'", 'Content-Encoding': 'gzip', 'Server': 'github.com', 'Accept-Ranges': 'bytes', 'X-RateLimit-Limit': '60', 'X-RateLimit-Remaining': '49', 'X-RateLimit-Reset': '1766122420', 'X-RateLimit-Resource': 'core', 'X-RateLimit-Used': '11', 'Content-Length': '4453', 'X-GitHub-Request-Id': '436A:2290E0:3A1B0D:43E65F:6944D72A'}
# application/json; charset=utf-8
# [{"id":"6852503372","type":"PushEvent","actor":{"id":65462025,"login":"shrikantdhanawade-github","display_login":"shrikantdhanawade-github","gravatar_id":"","url":"https://api.github.com/users/shrikantdhanawade-github","avatar_url":"https://avatars.githubusercontent.com/u/65462025?"},"repo":{"id":264490457,"name":"shrikantdhanawade-github/demo","url":"https://api.github.com/repos/shrikantdhanawade-github/demo"},"payload":{"repository_id":264490457,"push_id":29146427548,"ref":"refs/heads/master","head":"4522a3e5c2600c5f73cf20682b64e21ae708865e","before":"ddfa4492d7fdcddc069d621cf95d48e5025868b6"},"public":true,"created_at":"2025-12-19T04:35:05Z"},{"id":"6852503263","type":"CreateEvent","actor":{"id":166895733,"login":"swa-runner-app[bot]","display_login":"swa-runner-app","gravatar_id":"","url":"https://api.github.com/users/swa-runner-app[bot]","avatar_url":"https://avatars.githubusercontent.com/u/166895733?"},"repo":{"id":1119309011,"name":"static-web-apps-testing-org/swac4924e318eab43cc9ce232a971ea3af0","url":"https://api.github.com/repos/static-web-apps-testing-org/swac4924e318eab43cc9ce232a971ea3af0"},"payload":{"ref":"main","ref_type":"branch","full_ref":"refs/heads/main","master_branch":"main","description":"swac4924e318eab43cc9ce232a971ea3af0","pusher_type":"user"},"public":true,"created_at":"2025-12-19T04:35:04Z","org":{"id":96167003,"login":"static-web-apps-testing-org","gravatar_id":"","url":"https://api.github.com/orgs/static-web-apps-testing-org","avatar_url":"https://avatars.githubusercontent.com/u/96167003?"}},{"id":"6852503450","type":"PushEvent","actor":{"id":41898282,"login":"github-actions[bot]","display_login":"github-actions","gravatar_id":"","url":"https://api.github.com/users/github-actions[bot]","avatar_url":"https://avatars.githubusercontent.com/u/41898282?"},"repo":{"id":1000642111,"name":"pkgforge-go/builder","url":"https://api.github.com/repos/pkgforge-go/builder"},"payload":{"repository_id":1000642111,"push_id":29146427595,"ref":"refs/heads/metadata","head":"24b8e86743cc9012d11711b9f9b5cbc90eeec622","before":"dec60c134b9d189ba7dcdd813432e1b5c12763df"},"public":true,"created_at":"2025-12-19T04:35:05Z","org":{"id":215956125,"login":"pkgforge-go","gravatar_id":"","url":"https://api.github.com/orgs/pkgforge-go","avatar_url":"https://avatars.githubusercontent.com/u/215956125?"}},{"id":"6852503449","type":"PushEvent","actor":{"id":10938672,"login":"moazizdev","display_login":"moazizdev","gravatar_id":"","url":"https://api.github.com/users/moazizdev","avatar_url":"https://avatars.githubusercontent.com/u/10938672?"},"repo":{"id":1045194137,"name":"moazizdev/feed","url":"https://api.github.com/repos/moazizdev/feed"},"payload":{"repository_id":1045194137,"push_id":29146427627,"ref":"refs/heads/main","head":"f03d6e70255b566db2c4508bd95ea84a40dc5ab1","before":"8de848f6f13f45153584d35e3017447a8427c997"},"public":true,"created_at":"2025-12-19T04:35:05Z"},{"id":"6852503445","type":"PushEvent","actor":{"id":19896354,"login":"Kyome22","display_login":"Kyome22","gravatar_id":"","url":"https://api.github.com/users/Kyome22","avatar_url":"https://avatars.githubusercontent.com/u/19896354?"},"repo":{"id":904571662,"name":"cybozu/swift-kintone-rest-api","url":"https://api.github.com/repos/cybozu/swift-kintone-rest-api"},"payload":{"repository_id":904571662,"push_id":29146427621,"ref":"refs/heads/main","head":"57f820ae79acb3d56f0704993470c8a1b0b0fb05","before":"fdbc91f9fa486ebc0e498033ab525391cadd9cb5"},"public":true,"created_at":"2025-12-19T04:35:05Z","org":{"id":2433152,"login":"cybozu","gravatar_id":"","url":"https://api.github.com/orgs/cybozu","avatar_url":"https://avatars.githubusercontent.com/u/2433152?"}},{"id":"6852503364","type":"PushEvent","actor":{"id":39814207,"login":"pull[bot]","display_login":"pull","gravatar_id":"","url":"https://api.github.com/users/pull[bot]","avatar_url":"https://avatars.githubusercontent.com/u/39814207?"},"repo":{"id":1020908030,"name":"support-sg/CIPP-API","url":"https://api.github.com/re ...

# %%
import requests 

url = 'https://api.github.com/events'
response = requests.get(url)

content = response.json()
print(content)
print(type(content))
# Out:
# [{'id': '6852503372', 'type': 'PushEvent', 'actor': {'id': 65462025, 'login': 'shrikantdhanawade-github', 'display_login': 'shrikantdhanawade-github', 'gravatar_id': '', 'url': 'https://api.github.com/users/shrikantdhanawade-github', 'avatar_url': 'https://avatars.githubusercontent.com/u/65462025?'}, 'repo': {'id': 264490457, 'name': 'shrikantdhanawade-github/demo', 'url': 'https://api.github.com/repos/shrikantdhanawade-github/demo'}, 'payload': {'repository_id': 264490457, 'push_id': 29146427548, 'ref': 'refs/heads/master', 'head': '4522a3e5c2600c5f73cf20682b64e21ae708865e', 'before': 'ddfa4492d7fdcddc069d621cf95d48e5025868b6'}, 'public': True, 'created_at': '2025-12-19T04:35:05Z'}, {'id': '6852503263', 'type': 'CreateEvent', 'actor': {'id': 166895733, 'login': 'swa-runner-app[bot]', 'display_login': 'swa-runner-app', 'gravatar_id': '', 'url': 'https://api.github.com/users/swa-runner-app[bot]', 'avatar_url': 'https://avatars.githubusercontent.com/u/166895733?'}, 'repo': {'id': 1119309011, 'name': 'static-web-apps-testing-org/swac4924e318eab43cc9ce232a971ea3af0', 'url': 'https://api.github.com/repos/static-web-apps-testing-org/swac4924e318eab43cc9ce232a971ea3af0'}, 'payload': {'ref': 'main', 'ref_type': 'branch', 'full_ref': 'refs/heads/main', 'master_branch': 'main', 'description': 'swac4924e318eab43cc9ce232a971ea3af0', 'pusher_type': 'user'}, 'public': True, 'created_at': '2025-12-19T04:35:04Z', 'org': {'id': 96167003, 'login': 'static-web-apps-testing-org', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/static-web-apps-testing-org', 'avatar_url': 'https://avatars.githubusercontent.com/u/96167003?'}}, {'id': '6852503450', 'type': 'PushEvent', 'actor': {'id': 41898282, 'login': 'github-actions[bot]', 'display_login': 'github-actions', 'gravatar_id': '', 'url': 'https://api.github.com/users/github-actions[bot]', 'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'}, 'repo': {'id': 1000642111, 'name': 'pkgforge-go/builder', 'url': 'https://api.github.com/repos/pkgforge-go/builder'}, 'payload': {'repository_id': 1000642111, 'push_id': 29146427595, 'ref': 'refs/heads/metadata', 'head': '24b8e86743cc9012d11711b9f9b5cbc90eeec622', 'before': 'dec60c134b9d189ba7dcdd813432e1b5c12763df'}, 'public': True, 'created_at': '2025-12-19T04:35:05Z', 'org': {'id': 215956125, 'login': 'pkgforge-go', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/pkgforge-go', 'avatar_url': 'https://avatars.githubusercontent.com/u/215956125?'}}, {'id': '6852503449', 'type': 'PushEvent', 'actor': {'id': 10938672, 'login': 'moazizdev', 'display_login': 'moazizdev', 'gravatar_id': '', 'url': 'https://api.github.com/users/moazizdev', 'avatar_url': 'https://avatars.githubusercontent.com/u/10938672?'}, 'repo': {'id': 1045194137, 'name': 'moazizdev/feed', 'url': 'https://api.github.com/repos/moazizdev/feed'}, 'payload': {'repository_id': 1045194137, 'push_id': 29146427627, 'ref': 'refs/heads/main', 'head': 'f03d6e70255b566db2c4508bd95ea84a40dc5ab1', 'before': '8de848f6f13f45153584d35e3017447a8427c997'}, 'public': True, 'created_at': '2025-12-19T04:35:05Z'}, {'id': '6852503445', 'type': 'PushEvent', 'actor': {'id': 19896354, 'login': 'Kyome22', 'display_login': 'Kyome22', 'gravatar_id': '', 'url': 'https://api.github.com/users/Kyome22', 'avatar_url': 'https://avatars.githubusercontent.com/u/19896354?'}, 'repo': {'id': 904571662, 'name': 'cybozu/swift-kintone-rest-api', 'url': 'https://api.github.com/repos/cybozu/swift-kintone-rest-api'}, 'payload': {'repository_id': 904571662, 'push_id': 29146427621, 'ref': 'refs/heads/main', 'head': '57f820ae79acb3d56f0704993470c8a1b0b0fb05', 'before': 'fdbc91f9fa486ebc0e498033ab525391cadd9cb5'}, 'public': True, 'created_at': '2025-12-19T04:35:05Z', 'org': {'id': 2433152, 'login': 'cybozu', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/cybozu', 'avatar_url': 'https://avatars.githubusercontent.com/u/2433152?'}}, {'id': '6852503364', 'type': 'PushEvent', 'actor': {'id': 39814207, 'login': 'pull[bot]', ...
# <class 'list'>

# %%
import requests 

url = 'https://api.github.com/events'
response = requests.get(url)

print(response.json()[0]['type'])
# Out:
# PushEvent

# %%
import requests 

url = 'https://api.github.com/events'
response = requests.get(url)

# if response.headers['Content-Type'] == 'application/json':
#     print(response.json()[0]['type'])

if 'application/json' in response.headers.get('Content-Type' , ''):
    print(response.json()[0]['type'])
# Out:
# PushEvent

# %%
import requests

url = 'https://api.github.com/events'
response = requests.get(url)

data = response.json()   

for i in range(len(data)):
    print(data[i][101])

# %%
import requests

url = "https://api.github.com/events"
response = requests.get(url)

if response.status_code == 200:
    print(response.text)

else:
    print("Error:", response.status_code)

# %%
import requests

url = "https://api.github.com/events"
response = requests.get(url)

if response.status_code == 200:
    print('Fetching Successfully')
    print(response.text[:100])
else:
    print('Error Fetching Data' , response.status_code)
# Out:
# Fetching Successfully
# [{"id":"6852530042","type":"PushEvent","actor":{"id":216687169,"login":"5zandorcvh3U","display_login

# %%
import requests

#Data to be sent in a form
data = {'username' : 'user', 'passowrd' : 'pass'}

#URL where the form should be submitted 
response = requests.post('https://httpbin.org/post' , data)

if response.status_code == 200:
    print('Login Successful')
    print(response.text)
else:
    print('Login Failed' , response.status_code)
# Out:
# Login Successful
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "passowrd": "pass",
#     "username": "user"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "27",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.32.5",
#     "X-Amzn-Trace-Id": "Root=1-6944d9eb-0eec045245b0e31325cd0f0e"
#   },
#   "json": null,
#   "origin": "175.157.243.163",
#   "url": "https://httpbin.org/post"
# }

# %%
#using request library

base_url = 'https://example-shop'
params = {
    'product_id' : 1001,
    'size' : 'XL'
}

response = requests.get(url , params=params)
print(response)

# %%
import requests

#Example url for demostration
url = 'https://jsonplaceholder.typicode.com/posts'

#parameters you want to send
params = {
    'userId' : 1,
    'id' : 2
}

#making the request
response = requests.get(url , params=params)

#The actual url send would be something like this:
    # https://jsonplaceholder.typicode.com/posts?userId=1&id=2
print(response.url)
print(response.text)
# Out:
# https://jsonplaceholder.typicode.com/posts?userId=1&id=2
# [
#   {
#     "userId": 1,
#     "id": 2,
#     "title": "qui est esse",
#     "body": "est rerum tempore vitae\nsequi sint nihil reprehenderit dolor beatae ea dolores neque\nfugiat blanditiis voluptate porro vel nihil molestiae ut reiciendis\nqui aperiam non debitis possimus qui neque nisi nulla"
#   }
# ]

# %%
import requests

#Example URL for demostration
url ='https://httpbin.org/get'

#Credentials
username = 'user'
password = 'pass'

#Sending get request with basic Authentication
response = requests.get(url , auth=(username , password))

#Check if the request is success or not
if response.status_code == 200:
    print('Authentication Success!')
    print(response.text)
else:
    print('Authentication Failed' , response.status_code)
# Out:
# Authentication Success!
# {
#   "args": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Authorization": "Basic dXNlcjpwYXNz",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.32.5",
#     "X-Amzn-Trace-Id": "Root=1-6944e6ef-5253cfce662ee7576ca03cd8"
#   },
#   "origin": "175.157.243.163",
#   "url": "https://httpbin.org/get"
# }

# %%
from bs4 import BeautifulSoup

# %%
from bs4 import BeautifulSoup

html_doc = """<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

soup = BeautifulSoup(html_doc , 'html.parser')
# returns attribute
print(soup.p)
print(soup.a)
print(soup.title)

#returns method
print(soup.find('p'))
print(soup.find('a'))

print(soup.title.text)
# Out:
# <p class="title"><b>The Dormouse's story</b></p>
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
# <title>The Dormouse's story</title>
# <p class="title"><b>The Dormouse's story</b></p>
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
# The Dormouse's story

# %%
from bs4 import BeautifulSoup

html_doc = """<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

soup = BeautifulSoup(html_doc , 'html.parser')

print(soup.find_all('p'))
print(soup.find_all('a'))
# Out:
# [<p class="title"><b>The Dormouse's story</b></p>, <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>, <p class="story">...</p>]
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>, <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>, <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
import requests
from bs4 import BeautifulSoup

base_url = 'http://example.com'
response = requests.get(url)
data = response.text

if response.status_code == 200:
    print('Fetching Success!')
    print(response.headers)
    print(data)
else:
    print('Failed to Fetch' , response.status_code)
# Out:
# Fetching Success!
# {'Date': 'Fri, 19 Dec 2025 06:39:44 GMT', 'Content-Type': 'application/json', 'Content-Length': '309', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}
# {
#   "args": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.32.5",
#     "X-Amzn-Trace-Id": "Root=1-6944f330-46327493010be2e14e2f382d"
#   },
#   "origin": "175.157.243.163",
#   "url": "https://httpbin.org/get"
# }

# %%
import requests
from bs4 import BeautifulSoup

base_url = 'http://example.com'  

response = requests.get(base_url)

if response.status_code == 200:
    print('Fetching Success!')
    #print(response.headers)
    #print(response.text)

    soup = BeautifulSoup(response.text, 'html.parser')
    print(soup.h1.text)
else:
    print('Failed to Fetch', response.status_code)
# Out:
# Fetching Success!
# Example Domain

# %%
import requests
from bs4 import BeautifulSoup

base_url = 'http://example.com'  

response = requests.get(base_url)

if response.status_code == 200:
    print('Fetching Success!')
    soup = BeautifulSoup(response.text, 'html.parser')
    h1_tag = soup.find('h1')
    if h1_tag:
        print(h1_tag.text)
    else:
        print('H1 tag not found')
else:
    print('Failed to Fetch', response.status_code)
# Out:
# Fetching Success!
# Example Domain

# %%
import requests

base_url = 'https://api.open-meteo.com/v1/forecast'

params = {
    'latitude' : 6.7110,
    'longitude' : 79.9098,
    "current": "temperature_2m,wind_speed_10m"
}

response = requests.get(base_url, params=params)
print(response.text)
# Out:
# {"latitude":6.75,"longitude":80.0,"generationtime_ms":0.0013113021850585938,"utc_offset_seconds":0,"timezone":"GMT","timezone_abbreviation":"GMT","elevation":7.0}
